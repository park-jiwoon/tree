# %%
import pandas as pd
import numpy as np
import scipy.stats as st

co2_data = pd.read_csv('/content/drive/MyDrive/간이프로젝트/기초지자체-기준-지역-온실가스-배출량_2016-2020_-공표.csv', encoding='utf-8', header=2)

co2_company = pd.read_csv('/content/drive/MyDrive/간이프로젝트/온실가스-에너지-목표관리-명세서-주요정보.csv',encoding='utf-8')

# %%
co2_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   번호          249 non-null    object
#  1   광역          245 non-null    object
#  2   기초          245 non-null    object
#  3   VKT기준*      245 non-null    object
#  4   연료 공급량기준**  245 non-null    object
# dtypes: object(5)
# memory usage: 10.1+ KB

# %%
co2_data.head()
# Out:
#   번호  광역    기초 VKT기준* 연료 공급량기준**
# 0  1  서울    광역   바로가기       바로가기
# 1  2  서울   종로구   바로가기       바로가기
# 2  3  서울    중구   바로가기       바로가기
# 3  4  서울  동대문구   바로가기       바로가기
# 4  5  서울   성동구   바로가기       바로가기

# %%
co2_company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1102 entries, 0 to 1101
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   번호                1102 non-null   int64
#  1   관장기관              1102 non-null   object
#  2   법인명               1102 non-null   object
#  3   대상년도              1102 non-null   int64
#  4   지정구분              1102 non-null   object
#  5   지정업종              1102 non-null   object
#  6   온실가스 배출량(tCO₂eq)  1102 non-null   object
#  7   에너지 사용량(TJ)       1099 non-null   object
#  8   검증수행기관            1102 non-null   object
#  9   비고                0 non-null      float64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 86.2+ KB

# %%
co2_company.head()
# Out:
#    번호   관장기관                  법인명  대상년도 지정구분    지정업종 온실가스 배출량(tCO₂eq)  \
# 0   1    환경부              (유)남해환경  2022  사업장     폐기물            30113
# 1   2    환경부  (유)에스케이씨에보닉페록사이드코리아  2022   업체      산업            52658
# 2   3    환경부                (유)청명  2022  사업장     폐기물            13696
# 3   4  국토교통부              (유)호남고속  2022  사업장  교통(여객)            20519
# 4   5    환경부   (주)HJ매그놀리아용평호텔앤리조트  2022  사업장      건물            36552
#
#   에너지 사용량(TJ)      검증수행기관  비고
# 0         154   (재)한국품질재단 NaN
# 1        1078   (재)한국품질재단 NaN
# 2         277    ㈜한국품질보증원 NaN
# 3         322  (주)한국경영인증원 NaN
# 4         726   (재)한국품질재단 NaN

# %%
print(co2_company['관장기관'].unique())
print('\n')
print(co2_company['지정구분'].unique())
print('\n')
print(co2_company['지정업종'].unique())
print('\n')
print(co2_company['검증수행기관'].unique())
# Out:
# ['환경부' '국토교통부' '산업통상자원부' '해양수산부' '농림축산식품부']
#
#
# ['사업장' '업체']
#
#
# ['폐기물' '산업' '교통(여객)' '건물' '수송' '기계' '석유화학' '전기전자' '섬유' '교통(해운)' '자동차'
#  '식료품 제조업' '건설' '철강' '반도체' '비철금속' '집단에너지' '시멘트' '교통(화물)' '전환' '목재' '조선'
#  '유리' '음료제조업' '광업' '수도사업' '발전에너지' '교통(철도)' '제지' '지정외 폐기물처리업 등' '공공ㆍ기타'
#  '담배제조업' '요업' '하수처리업' '산업단지' '디스플레이' '음식료품' '통신']
#
#
# ['(재)한국품질재단' '㈜한국품질보증원' '(주)한국경영인증원' '한국가스안전공사' '한국표준협회' '대일이엔씨기술(주)'
#  '지속가능인증원주식회사' '(재)한국화학융합시험연구원' '(주)비에스아이그룹코리아' '㈜디엔브이비즈니스어슈어런스코리아'
#  '로이드인증원㈜' '한국생산성본부인증원(주)' '(주)신화엔지니어링종합건축사사무소']

# %%
company_2021 = pd.read_csv('/content/drive/MyDrive/간이프로젝트/온실가스-에너지-목표관리-명세서-주요정보-2021년.csv',encoding='utf-8')

# %%
print(company_2021.info())
company_2021.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1079 entries, 0 to 1078
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   번호                1079 non-null   int64
#  1   관장기관              1079 non-null   object
#  2   법인명               1079 non-null   object
#  3   대상년도              1079 non-null   int64
#  4   지정구분              1079 non-null   object
#  5   지정업종              1079 non-null   object
#  6   온실가스 배출량(tCO₂eq)  1079 non-null   object
#  7   에너지 사용량(TJ)       1079 non-null   object
#  8   검증수행기관            1079 non-null   object
#  9   비고                0 non-null      float64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 84.4+ KB
# None
#    번호     관장기관                  법인명  대상년도 지정구분    지정업종 온실가스 배출량(tCO₂eq)  \
# 0   1      환경부  (유)에스케이씨에보닉페록사이드코리아  2021   업체      산업            57349
# 1   2    국토교통부              (유)호남고속  2021  사업장  교통(여객)            19358
# ...

# %%
company_div_2021 = pd.read_csv('/content/drive/MyDrive/간이프로젝트/붙임1_-2021년도-업체별-명세서-주요정보__22.12.21-기준_.csv',encoding='utf-8')

# %%
print(company_div_2021.info())
company_div_2021.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 623 entries, 0 to 622
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   0 non-null      float64
#  1   Unnamed: 1   619 non-null    object
#  2   Unnamed: 2   604 non-null    object
#  3   Unnamed: 3   620 non-null    object
#  4   Unnamed: 4   619 non-null    object
#  5   Unnamed: 5   604 non-null    object
#  6   Unnamed: 6   11 non-null     object
#  7   Unnamed: 7   1 non-null      object
#  8   Unnamed: 8   604 non-null    object
#  9   Unnamed: 9   1 non-null      object
#  10  Unnamed: 10  619 non-null    object
# dtypes: float64(1), object(10)
# memory usage: 53.7+ KB
# None
#    Unnamed: 0 Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4  \
# 0         NaN        NaN        NaN     관리업체별 명세서 제출 현황        NaN
# 1         NaN        NaN        NaN                 NaN        NaN
# ...

# %%
upjong_2021 = pd.read_csv('/content/drive/MyDrive/간이프로젝트/붙임2_-2021년도-업종별-명세서-주요정보_23.12.21-기준_.csv',encoding='utf-8')

# %%
print(upjong_2021.info())
upjong_2021.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 623 entries, 0 to 622
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   0 non-null      float64
#  1   Unnamed: 1   619 non-null    object
#  2   Unnamed: 2   604 non-null    object
#  3   Unnamed: 3   620 non-null    object
#  4   Unnamed: 4   619 non-null    object
#  5   Unnamed: 5   604 non-null    object
#  6   Unnamed: 6   11 non-null     object
#  7   Unnamed: 7   1 non-null      object
#  8   Unnamed: 8   604 non-null    object
#  9   Unnamed: 9   1 non-null      object
#  10  Unnamed: 10  619 non-null    object
# dtypes: float64(1), object(10)
# memory usage: 53.7+ KB
# None
#    Unnamed: 0 Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4  \
# 0         NaN        NaN        NaN     관리업체별 명세서 제출 현황        NaN
# 1         NaN        NaN        NaN                 NaN        NaN
# ...

# %%
region_2021 = pd.read_csv('/content/drive/MyDrive/간이프로젝트/붙임3_-2021년도-지역별-온실가스-배출량_23.12.21-기준_.csv',encoding='utf-8')

# %%
print(region_2021.info())
region_2021.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 9 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   2021년도 지역별 온실가스 배출량                        < 2022.12.21. 명세서 기준 >  20 non-null     object
#  1   Unnamed: 1                                                         19 non-null     object
#  2   Unnamed: 2                                                         19 non-null     object
#  3   Unnamed: 3                                                         19 non-null     object
#  4   Unnamed: 4                                                         19 non-null     object
#  5   Unnamed: 5                                                         0 non-null      float64
#  6   Unnamed: 6                                                         0 non-null      float64
# ...
